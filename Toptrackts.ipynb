# %% [markdown]
# What was the most-played song from 2015 to 2025 on Spotify?

# %% [markdown]
# # Study: To answer this question, I would collect data from major music streaming platforms like Spotify, Apple Music, and YouTube. The goal is to identify which song had the highest number of plays during 2015–2025. I would rely on: Official yearly streaming summaries, Global chart rankings, Track-level streaming statistics (like total stream counts)
#
# The most-played song will be determined by comparing the total accumulated streams across all platforms.

# %% [markdown]
# # Type of study: This would be a retrospective observational study because I'm looking back at existing data that has already been recorded over the past 10 years without changing anything or influencing the outcome.

# %% [markdown]
# # The dataset shown above is compiled from Spotify’s public global streaming data (via OpenDataBay and Spotify Charts). Each record includes: The song's Spotify ID, Song title, artist, Total stream count, Average daily streams Release year. This data is primarily derived from Spotify’s Top 200 charts, which report weekly song rankings and stream counts globally.

# %% [markdown]
# # In short, the data set focuses on mainstream, high-performing tracks that show strong global presence on Spotify.

# %% [markdown]
# # This study aims to find the most-played song from 2015 to 2025 by gathering play count data from major streaming platforms. The current dataset, based on Spotify charts, is a strong starting point but may favor mainstream, Western-pop songs and exclude cross-platform hits or non-charting tracks. Including additional platforms like Apple Music and YouTube would improve fairness and reduce bias.

# %%
import pandas as pd

# Create the dataset
data = {
    "Rank": list(range(1, 26)),
    "Spotify_ID": [
        "ab67616d0000b2738863bc11d2aa12b54f5aeb36",
        "ab67616d0000b273ba5db46f4b838ef6027e6f96",
        "ab67616d0000b273ba5db46f4b838ef6027e6f96",
        "ab67616d00004851b5097b81179824803664aaaf",
        "ab67616d0000b2737b9639babbe96e25071ec1d4",
        "ab67616d0000b2734718e2b124f79258be7bc452",
        "ab67616d000048514718e2b124f79258be7bc452",
        "ab67616d000048517177fb5667cdafd34b871257",
        "ab67616d0000b2739478c87599550dd73bfa7e02",
        "ab67616d000048512e8ed79e177ff6011076f5f0",
        "ab67616d0000b273ef0d4234e1a645740f77d59c",
        "ab67616d000048519e495fb707973f3390850eea",
        "ab67616d0000b2730bffddcd4c83baab8303c44d",
        "ab67616d0000b2735675e83f707f1d7271e5cf8a",
        "ab67616d0000b2739416ed64daf84936d89e671c",
        "ab67616d00004851c4d537d8c91fcecf90bc9454",
        "ab67616d000048518e6551a2944764bc8e33a960",
        "ab67616d00004851d4daf28d55fe4197ede848be",
        "ab67616d00004851b4ad7ebaf4575f120eb3f193",
        "ab67616d000048511fa318e90c9d4ddc6b480853",
        "ab67616d0000b2730c13d3d5a503c84fcc60ae94",
        "ab67616d0000b2737c3b8acbb943c8da17364f34",
        "ab67616d0000b2738a3f0a3ca7929dea23cd274c",
        "ab67616d0000b27320beb61f61fcbeb33b10a9ab",
        "ab67616d0000b273aa1beea495a0070294c30e31"
    ],
    "Song": [
        "Blinding Lights", "Shape of You", "Perfect", "Save Your Tears", "Someone You Loved",
        "Starboy", "Die For You", "Sweater Weather", "Sunflower", "As It Was",
        "Despacito", "Heat Waves", "Goosebumps", "Believer", "One Dance",
        "Another Love", "Stay", "Levitating [DaBaby Remix]", "Numb", "The Night We Met",
        "Something Just Like This", "Closer", "Lovely", "Say You Won't Let Go", "Dance Monkey"
    ],
    "Artist": [
        "The Weeknd", "Ed Sheeran", "Ed Sheeran", "The Weeknd", "Lewis Capaldi",
        "The Weeknd ft. Daft Punk", "The Weeknd", "The Neighbourhood", "Post Malone & Swae Lee",
        "Harry Styles", "Luis Fonsi ft. Daddy Yankee", "Glass Animals", "Travis Scott ft. Kendrick Lamar",
        "Imagine Dragons", "Drake ft. Wizkid & Kyla", "Tom Odell", "The Kid Laroi & Justin Bieber",
        "Dua Lipa ft. DaBaby", "Linkin Park", "Lord Huron", "The Chainsmokers & Coldplay",
        "The Chainsmokers ft. Halsey", "Billie Eilish & Khalid", "James Arthur", "Tones And I"
    ],
    "Streams": [
        5101127155, 5065525299, 4848169054, 4390697725, 4180149443,
        4152739501, 4150434760, 4106977542, 4017367374, 4013379155,
        3913966600, 3906069250, 3776420697, 3761091156, 3758833566,
        3676922012, 3642105200, 3628830916, 3610988753, 3554149561,
        3489875865, 3488172181, 3432456609, 3411491560, 3358228164
    ],
    "Daily_Streams": [
        1575561, 1635702, 1711058, 1838960, 1172674,
        1625437, 1725479, 2100859, 1183808, 1174922,
        937126, 1172006, 1053690, 1215367, 1227797,
        1733431, 1029921, 1209630, 1708836, 2679375,
        1390881, 1174262, 1067208, 1009412, 589263
    ],
    "Year": [
        2019, 2017, 2017, 2020, 2018,
        2016, 2016, 2012, 2018, 2022,
        2017, 2020, 2016, 2017, 2016,
        2013, 2021, 2020, 2003, 2015,
        2017, 2016, 2018, 2016, 2019
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Show first few rows
print(df.head())
# Out:
#    Rank                                Spotify_ID               Song  \
# 0     1  ab67616d0000b2738863bc11d2aa12b54f5aeb36    Blinding Lights
# 1     2  ab67616d0000b273ba5db46f4b838ef6027e6f96       Shape of You
# 2     3  ab67616d0000b273ba5db46f4b838ef6027e6f96            Perfect
# 3     4  ab67616d00004851b5097b81179824803664aaaf    Save Your Tears
# 4     5  ab67616d0000b2737b9639babbe96e25071ec1d4  Someone You Loved
#
#           Artist     Streams  Daily_Streams  Year
# 0     The Weeknd  5101127155        1575561  2019
# 1     Ed Sheeran  5065525299        1635702  2017
# 2     Ed Sheeran  4848169054        1711058  2017
# 3     The Weeknd  4390697725        1838960  2020
# 4  Lewis Capaldi  4180149443        1172674  2018

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset (make sure you already have your DataFrame called df)
# Replace this with your actual DataFrame if you already loaded it

# Create a frequency table for the "Year" variable
frequency_table = df['Year'].value_counts().sort_index()

# Convert to DataFrame
freq_df = frequency_table.reset_index()
freq_df.columns = ['Year', 'Song Count']

# Plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=freq_df, x='Year', y='Song Count', palette='viridis')

plt.title('Number of Songs per Release Year (Top 25 Most-Played Songs)')
plt.xlabel('Year')
plt.ylabel('Frequency (Song Count)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()
